# %% [markdown]
# <a href="https://colab.research.google.com/github/133t-h4x0r/womenline-week-01/blob/main/Women_Line_week_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas scikit-learn

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0d98085-e02d-48aa-bff7-1994b0d90f53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0d98085-e02d-48aa-bff7-1994b0d90f53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = pd.read_csv("annotated_prompts_with_intent.csv")
print(data.head())
# Out:
#                                               Prompt  \
# 0  How does chronic stress affect the menstrual c...
# 1  What are common emotional symptoms of PMS and ...
# 2  What is PMDD and how does it differ from PMS i...
# 3  How can teenage girls cope with anxiety and mo...
# 4  What lifestyle habits (diet, exercise, sleep) ...
#
#                                    Hindi Translation  \
# 0  क्रोनिक तनाव मासिक धर्म चक्र को कैसे प्रभावित ...
# 1  पीएमएस के सामान्य भावनात्मक लक्षण क्या हैं और ...
# 2  PMDD क्या है और यह लक्षणों और उपचार के मामले म...
# 3  किशोर लड़कियां अपने मासिक धर्म से संबंधित चिंत...
# 4  क्या जीवनशैली की आदतें (आहार, व्यायाम, नींद) म...
#
#                                Code-Mixed (Hinglish)           Intent  \
# 0  How does chronic stress affect the menstrual c...  mental_wellness
# 1  What are common emotional symptoms of PMS and ...  mental_wellness
# 2  What is PMDD and how does it differ from PMS i...      diet_advice
# ...

# %%
import pandas as pd

data = pd.read_csv('annotated_prompts_with_intent.csv')
print(data.head())
# Out:
#                                               Prompt  \
# 0  How does chronic stress affect the menstrual c...
# 1  What are common emotional symptoms of PMS and ...
# 2  What is PMDD and how does it differ from PMS i...
# 3  How can teenage girls cope with anxiety and mo...
# 4  What lifestyle habits (diet, exercise, sleep) ...
#
#                                    Hindi Translation  \
# 0  क्रोनिक तनाव मासिक धर्म चक्र को कैसे प्रभावित ...
# 1  पीएमएस के सामान्य भावनात्मक लक्षण क्या हैं और ...
# 2  PMDD क्या है और यह लक्षणों और उपचार के मामले म...
# 3  किशोर लड़कियां अपने मासिक धर्म से संबंधित चिंत...
# 4  क्या जीवनशैली की आदतें (आहार, व्यायाम, नींद) म...
#
#                                Code-Mixed (Hinglish)           Intent  \
# 0  How does chronic stress affect the menstrual c...  mental_wellness
# 1  What are common emotional symptoms of PMS and ...  mental_wellness
# 2  What is PMDD and how does it differ from PMS i...      diet_advice
# ...

# %%
print(data.columns)
# Out:
# Index(['Prompt', 'Hindi Translation', 'Code-Mixed (Hinglish)', 'Intent',
#        'Context', 'Tags', 'Tamil Translation', 'Bengali Translation',
#        'Marathi Translation', 'Urdu Translation', 'Telugu Translation',
#        'valid_prompt', 'Symptom', 'Sentiment', 'Language'],
#       dtype='object')

# %%
print(data.head())
# Out:
#                                               Prompt  \
# 0  How does chronic stress affect the menstrual c...
# 1  What are common emotional symptoms of PMS and ...
# 2  What is PMDD and how does it differ from PMS i...
# 3  How can teenage girls cope with anxiety and mo...
# 4  What lifestyle habits (diet, exercise, sleep) ...
#
#                                    Hindi Translation  \
# 0  क्रोनिक तनाव मासिक धर्म चक्र को कैसे प्रभावित ...
# 1  पीएमएस के सामान्य भावनात्मक लक्षण क्या हैं और ...
# 2  PMDD क्या है और यह लक्षणों और उपचार के मामले म...
# 3  किशोर लड़कियां अपने मासिक धर्म से संबंधित चिंत...
# 4  क्या जीवनशैली की आदतें (आहार, व्यायाम, नींद) म...
#
#                                Code-Mixed (Hinglish)           Intent  \
# 0  How does chronic stress affect the menstrual c...  mental_wellness
# 1  What are common emotional symptoms of PMS and ...  mental_wellness
# 2  What is PMDD and how does it differ from PMS i...      diet_advice
# ...

# %%
X = data['Prompt']
y = data['Intent']

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5
#
# Classification Report:
#                     precision    recall  f1-score   support
#
#       diet_advice       0.00      0.00      0.00         1
# exercise_guidance       0.00      0.00      0.00         2
#   mental_wellness       0.73      0.62      0.67        13
#      myth_busting       0.00      0.00      0.00         1
#     symptom_query       0.25      0.67      0.36         3
#
#          accuracy                           0.50        20
#         macro avg       0.20      0.26      0.21        20
#      weighted avg       0.51      0.50      0.49        20
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
user_input = ["How to handle teenage anxiety?"]
input_vector = vectorizer.transform(user_input)
prediction = model.predict(input_vector)
print("Predicted Intent:", prediction[0])
# Out:
# Predicted Intent: mental_wellness

# %%
user_input = input("Ask your question: ")

# Check if question is relevant
if any(word in user_input.lower() for word in ["stress", "diet", "anxiety", "self-care"]):
    input_vector = vectorizer.transform([user_input])
    prediction = model.predict(input_vector)
    print("Predicted Intent:", prediction[0])
else:
    print("Can you please provide more specific details?")

# Feedback
feedback = input("Was this response helpful? (yes/no): ")
print("Thanks for your feedback!")
# Out:
# Ask your question: diet
# Predicted Intent: mental_wellness
# Was this response helpful? (yes/no): no
# Thanks for your feedback!
